# %% [markdown]
# # 03 - Retrieval from First Principles
#
# **FinAI Academy - Arnaud Demes**
#
# Build a lexical search baseline before adding embeddings.

# %% [markdown]
# ## Learning objectives
#
# - Implement TF-IDF retrieval.
# - Explain cosine similarity and top-k.
# - Evaluate retrieval separately from answer generation.

# %%
documents = [
    "Revenue increased while operating margin declined.",
    "The company identified supply-chain concentration as a risk.",
    "Free cash flow improved during the reporting period.",
]
query = "What risks did the company report?"

# %% [markdown]
# ## Checkpoint
#
# 1. Why start with a lexical baseline?
# 2. What does increasing top-k trade off?
# 3. Which queries benefit from exact matching?
