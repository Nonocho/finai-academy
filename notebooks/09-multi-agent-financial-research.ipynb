# %% [markdown]
# # 09 - Multi-Agent Financial Research
#
# **FinAI Academy - Arnaud Demes**
#
# Coordinate specialist agents under a bounded supervisor.

# %% [markdown]
# ## Learning objectives
#
# - Decompose a research request into specialist tasks.
# - Limit the tools available to each specialist.
# - Produce an observable execution trace and final synthesis.

# %%
specialists = {
    "price_analyst": ["historical_prices"],
    "filing_analyst": ["filing_sections"],
    "synthesizer": [],
}
specialists

# %% [markdown]
# ## Checkpoint
#
# 1. Why should agents have different tool scopes?
# 2. What belongs in shared state?
# 3. When is multi-agent orchestration unnecessary?
