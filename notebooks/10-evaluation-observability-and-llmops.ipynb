# %% [markdown]
# # 10 - Evaluation, Observability, and LLMOps
#
# **FinAI Academy - Arnaud Demes**
#
# Measure product quality and operational health as separate dimensions.

# %% [markdown]
# ## Learning objectives
#
# - Define retrieval, answer, and tool-use metrics.
# - Combine deterministic checks with model-based evaluation.
# - Interpret latency, token, throughput, and reliability signals.

# %%
evaluation_record = {
    "retrieval_recall_at_5": None,
    "groundedness": None,
    "tool_call_correct": None,
    "latency_ms": None,
    "input_tokens": None,
    "output_tokens": None,
}
evaluation_record

# %% [markdown]
# ## Checkpoint
#
# 1. Which failures require deterministic tests?
# 2. When is an LLM judge appropriate?
# 3. Why do infrastructure metrics not measure answer quality?
