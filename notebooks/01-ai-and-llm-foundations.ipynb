# %% [markdown]
# # 01 - AI and LLM Foundations
#
# **FinAI Academy - Arnaud Demes**
#
# Observe how inference settings and model constraints change behavior.

# %% [markdown]
# ## Learning objectives
#
# - Explain tokens, context windows, and generation controls.
# - Compare local and cloud deployment trade-offs.
# - Measure variability instead of assuming determinism.

# %%
comparison_dimensions = {
    "quality": None,
    "latency_ms": None,
    "context_tokens": None,
    "cost_per_request": None,
    "data_location": None,
}
comparison_dimensions

# %% [markdown]
# ## Checkpoint
#
# 1. Why is context not memory?
# 2. Which settings improve reproducibility?
# 3. When is a local model the better choice?
