# %% [markdown]
# # 08 - LangGraph Agents and Self-Correction
#
# **FinAI Academy - Arnaud Demes**
#
# Build a bounded agent that can observe and recover from tool errors.

# %% [markdown]
# ## Learning objectives
#
# - Represent agent state explicitly.
# - Route between model and tool nodes.
# - Add retry limits and termination conditions.

# %%
agent_state = {
    "messages": [],
    "step_count": 0,
    "error_count": 0,
    "max_steps": 8,
    "max_errors": 3,
}
agent_state

# %% [markdown]
# ## Checkpoint
#
# 1. When should an error become an observation?
# 2. How do retries create infinite loops?
# 3. Which state must survive between nodes?
