# %% [markdown]
# # 06 - RAG with Evidence
#
# **FinAI Academy - Arnaud Demes**
#
# Generate answers whose factual claims are traceable to source evidence.

# %% [markdown]
# ## Learning objectives
#
# - Construct a bounded context from retrieved chunks.
# - Attach citations to individual claims.
# - Abstain when the evidence is insufficient or contradictory.

# %%
claim = {
    "text": "Operating margin declined during the quarter.",
    "source_id": "filing-2026-q2#management-discussion",
    "evidence": None,
    "supported": None,
}
claim

# %% [markdown]
# ## Checkpoint
#
# 1. What makes a citation verifiable?
# 2. How should conflicting evidence be handled?
# 3. How do groundedness and correctness differ?
