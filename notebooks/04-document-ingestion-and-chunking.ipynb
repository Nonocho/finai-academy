# %% [markdown]
# # 04 - Document Ingestion and Chunking
#
# **FinAI Academy - Arnaud Demes**
#
# Preserve structure and meaning while preparing financial documents for retrieval.

# %% [markdown]
# ## Learning objectives
#
# - Compare fixed, recursive, heading-aware, and semantic chunking.
# - Preserve tables and financial metadata.
# - Estimate the value and cost of contextual enrichment.

# %%
chunking_experiment = {
    "strategy": "heading-aware",
    "target_tokens": 500,
    "overlap_tokens": 50,
    "preserve_tables": True,
}
chunking_experiment

# %% [markdown]
# ## Checkpoint
#
# 1. What does fixed-size chunking destroy?
# 2. Which metadata belongs on every chunk?
# 3. When is contextual enrichment justified?
