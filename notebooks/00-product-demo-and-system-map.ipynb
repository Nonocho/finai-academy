# %% [markdown]
# # 00 - Product Demo and System Map
#
# **FinAI Academy - Arnaud Demes**
#
# Map a complete financial AI product before building its individual components.

# %% [markdown]
# ## Learning objectives
#
# - Identify ingestion, retrieval, generation, tools, agents, and evaluation.
# - Separate deterministic components from model-driven components.
# - Locate evidence, approval, and observability boundaries.

# %%
system_components = [
    "document ingestion",
    "retrieval",
    "answer generation",
    "financial tools",
    "agent orchestration",
    "evaluation",
]
system_components

# %% [markdown]
# ## Checkpoint
#
# 1. Which components must be deterministic?
# 2. Where can unsupported claims enter the system?
# 3. Which actions require human approval?
