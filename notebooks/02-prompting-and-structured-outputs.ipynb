# %% [markdown]
# # 02 - Prompting and Structured Outputs
#
# **FinAI Academy - Arnaud Demes**
#
# Turn an ambiguous finance request into a testable prompt and output contract.

# %% [markdown]
# ## Learning objectives
#
# - Separate instructions, context, examples, and constraints.
# - Define typed response schemas.
# - Validate semantic correctness after syntax validation.

# %%
from pydantic import BaseModel, Field

class FinancialMetric(BaseModel):
    name: str
    value: float
    unit: str
    period: str = Field(description="Reporting period for the metric")

# %% [markdown]
# ## Checkpoint
#
# 1. What belongs in the schema rather than the prompt?
# 2. Can valid JSON still contain a hallucination?
# 3. Which business rules should Python enforce?
